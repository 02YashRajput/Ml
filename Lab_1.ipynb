# %% [markdown]
# <a href="https://colab.research.google.com/github/02YashRajput/Ml/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10,20,30,40,50,60,70])
y = np.array([100,120,140,160,180,200,220])
w = 0
b = 0
a = 0.0001
m = len(x)
iter = 1000
for i in range(iter):
    y_pred = w*x+b
    error = y_pred-y
    w =w- ((a/m)*np.sum((error*x)))
    b = b- ((a/m)*np.sum(error))

plt.plot(x, y, 'o', label='Data points')
plt.plot(x, (w * x + b), label='Regression line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Descent for Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
